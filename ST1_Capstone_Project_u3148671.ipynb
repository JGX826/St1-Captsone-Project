# %% [markdown]
# ## My Capstone Project - Assignment
# > #15 Football Data Cleaned
# > Sources dataset from Kaggle.com
#
#
# https://github.com/JGX826/St1-Captsone-Project.git

# %%
# %cd /content/drive/MyDrive/MyST1_CaptsoneProject
# Out:
# /content/drive/MyDrive/MyST1_CaptsoneProject

# %%
# !ls /content/drive/MyDrive/MyST1_CaptsoneProject
# Out:
# 'Australian Vehicle Prices.csv'   FootballData.csv

# %%
# !ls
'FootballData.csv'
# Out:
# 'Australian Vehicle Prices.csv'   FootballData.csv
# 'FootballData.csv'

# %% [markdown]
# ST1 Capstone Project is focused on data of FootballData that is available from Kaggle repository.
# *   There are 12,711 rows of data showing data different football players, showing their stats and professional details per row.
# * There are 11,920 rows of rows of data, after deleting duplicates.
# *   The Project is based upon the demonstration of multiple python library packages, in order to conduct data analytics, visualisation, prediction models and deployment capabilities in regard to a dataset.
# *   To conduct the project and demonstrate these technical data analytical skills, I will follow the steps outlined within the ST 1 Captsone Project Description and Requirements pdf, that provides step by step instructions that guides the algorithms and machine learning protocols to assist with the analyzing of the datasets that provides past data that has been collected on FootballData. In order to perform ML and regression analysis, various Python packages will be used as well.

# %% [markdown]
# **Step 1: Reading the FootballData dataset using Python**

# %%
# Suppressing the warning messages that may occur due to outdated packages used
# within the coding. Once imported, all the warnings within the rest of the
# python code, will be suppressed.
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
FootballData=pd.read_csv('/content/drive/MyDrive/MyST1_CaptsoneProject/FootballData.csv', encoding = 'latin')
print('Shape before deleting duplicate values:', FootballData.shape)


# Removing duplicate rows within the dataset
FootballData=FootballData.drop_duplicates()
print('Shape after deleting duplicate values:', FootballData.shape)

# Printing sample data
# Analyse the variables (45.26)
FootballData.head(10)
# Out:
# Shape before deleting duplicate values: (12711, 44)
# Shape after deleting duplicate values: (11920, 44)
#            name first_name  age       nation         league          team  \
# 0     Etheridge       Neil   28  Philippines  PremierLeague       Cardiff
# 1     LÃ©oNatel        NaN   21       Brazil  FirstDivision  APOELNicosia
# 2       Vidigal     AndrÃ©   20     Portugal  FirstDivision  APOELNicosia
# 3      Antoniou  BaiAndrew   21    Australia  FirstDivision  AlkiOroklini
# 4       Tribeau      Yoann   30       France  FirstDivision  AlkiOroklini
# 5   MarlonSilva        NaN   28       Brazil  FirstDivision  AlkiOroklini
# 6  Konstantinou  Stavrinos   21       Cyprus  FirstDivision  AlkiOroklini
# 7     Belameiri     ElHadi   27      Algeria  FirstDivision  AlkiOroklini
# 8        Acosta     Rafael   29    Venezuela  FirstDivision  AlkiOroklini
# 9     Spoljaric     Matija   21       Cyprus  FirstDivision  AlkiOroklini
#
# ...

# %% [markdown]
# **Observations from Step 1 regarding the data description of the FootballData set**
#
#
# *   This dataset file contains 12,711 rows of data.
# *   There are 44 columns
#
# Columns included within the dataset
#
# - name
# - first_name
# -	age	nation
# -	league	team
# -	goals_selection
# -	selections_nation
# -	position	price
# -	assist_continent
# -	own_goal_continent
# -	sub_on_continent
# -	sub_out_continent
# -	yellow_card_continent
# -	second_yellow_card_continent
# -	red_card_continent
# -	penalty_goal_continent
# -	conceded_goal_continent
# -	clean_sheet_continent

# %% [markdown]
# **Step 2: Problem Statement Definition**
#
# *   Creating a prediction model to predict the price (Price) of a football player.
# *   Target Variable: Price Predictors/Features: age, goals_selection, selections_nation, penalty_goal_continent, clean_sheet_continent and assist_continent
#
# Note: Price is being used a Categorical Variable for this assignment

# %% [markdown]
# **Step 3: Choosing the appropriate ML/AI Algorithm for Data Analysis**
#
#
# *   Based on the problem statement we need to create a supervised ML Regression model as the target variable (price) has been determined as being "categorical" given that it is predicting prices of the football players.

# %% [markdown]
# **Step 4: Observe the class distribution (Target variable distribution to check if the data is balanced or skewed)**
#
# *   Note: if target variable's distribution is too skewed then the predictive modeling will lead to poor results. (Lecture 9)
# * Ideally Bell curve is desirable but slightly positive skew or negative skew is also fine. (Lecture 9)
# * When performing Regression algorithm modelling and analysis, we need to make sure the histogram lo(Lecture 9)
# * Otherwise it impacts the Machine Learning algorithms ability to learn all the scenarios from the data.(Lecture 9)

# %%
# %matplotlib inline
# Creating histogram as the Target variable (price of the football player) is being treated categorical for this assignment
# This will show the distribution of the MEDV values
FootballData['price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# **Step 5: Basic Exploratory Data Analysis - (from Lecture 9)**
#
# - There are **four commands which are used for Basic data exploratory Analysis in Python**. (Lecture 9)
# - head(): This helps to see a few sample rows of the data
# - info(): This provides the summarized information of the data.
# - describe(): This provides the summarized information of the data.
# - describe(): This provides the descriptive statistical details of the data
# - nunique(): This helps us to identify if a column is a categorical or continuous.(Lecture 9)

# %%
# Looking at sample rows in the data
FootballData.tail()
# Out:
#           name first_name  age  nation    league           team  \
# 12706     Neto    Eduardo   30  Brazil  J1League  NagoyaGrampus
# 12707     Soma       Yuki   21   Japan  J1League  NagoyaGrampus
# 12708    Fujii     Haruya   18   Japan  J1League  NagoyaGrampus
# 12709   Takeda      Yohei   31   Japan  J1League  NagoyaGrampus
# 12710  Shibuya    Tsubasa   24   Japan  J1League  NagoyaGrampus
#
#        goals_selection  selections_nation           position    price  ...  \
# 12706                0                  0  DefensiveMidfield  1350000  ...
# 12707                0                  0         Midfielder    75000  ...
# 12708                0                  0           Defender    50000  ...
# 12709                0                  0         Goalkeeper   125000  ...
# 12710                0                  0         Goalkeeper   100000  ...
#
#        assist_continent  own_goal_continent  sub_on_continent  \
# 12706                 1                   0                 1
# ...

# %%
# Looking at the descriptive statistics of the data
# These statistics show the overall distribution through the usages of minimum and mean. - it gives an insight into how different variables can influence the overall distribution, especially if there is a data that is signficantly different from the rest.
FootballData.describe(include='all')
# Out:
#               name first_name           age  nation         league      team  \
# count        11920      10911  11920.000000   11920          11920     11920
# unique        9202       4610           NaN     167             74      1057
# top     RodrÃ­guez     Daniel           NaN  Brazil  PremierLeague  Nacional
# freq            47         76           NaN     847            686        32
# mean           NaN        NaN     26.082634     NaN            NaN       NaN
# std            NaN        NaN      4.579669     NaN            NaN       NaN
# min            NaN        NaN     16.000000     NaN            NaN       NaN
# 25%            NaN        NaN     23.000000     NaN            NaN       NaN
# 50%            NaN        NaN     26.000000     NaN            NaN       NaN
# 75%            NaN        NaN     29.000000     NaN            NaN       NaN
# max            NaN        NaN     46.000000     NaN            NaN       NaN
#
# ...

# %%
#Observing the summarized information of data
#Data types, Missing values based on number of non-null values Vs total rows etc.
# Remove those variables from data which have too many missing values (Missing Values > 30%)
# Remove Qualitative variabls which cannot be used in Machine Learning - with this approach, note any qualitative data for this assignment, will not be rated against a numerical system
# Note: it is using a class called "DataFrame"
FootballData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11920 entries, 0 to 12710
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          11920 non-null  object
#  1   first_name                    10911 non-null  object
#  2   age                           11920 non-null  int64
#  3   nation                        11920 non-null  object
#  4   league                        11920 non-null  object
#  5   team                          11920 non-null  object
#  6   goals_selection               11920 non-null  int64
#  7   selections_nation             11920 non-null  int64
#  8   position                      11920 non-null  object
#  9   price                         11920 non-null  int64
#  10  end_contract                  7958 non-null   float64
#  11  goal_champ                    11920 non-null  int64
# ...

# %%
# Looking at the descriptive statistics of the data
FootballData.describe(include='all')
# Out:
#               name first_name           age  nation         league      team  \
# count        11920      10911  11920.000000   11920          11920     11920
# unique        9202       4610           NaN     167             74      1057
# top     RodrÃ­guez     Daniel           NaN  Brazil  PremierLeague  Nacional
# freq            47         76           NaN     847            686        32
# mean           NaN        NaN     26.082634     NaN            NaN       NaN
# std            NaN        NaN      4.579669     NaN            NaN       NaN
# min            NaN        NaN     16.000000     NaN            NaN       NaN
# 25%            NaN        NaN     23.000000     NaN            NaN       NaN
# 50%            NaN        NaN     26.000000     NaN            NaN       NaN
# 75%            NaN        NaN     29.000000     NaN            NaN       NaN
# max            NaN        NaN     46.000000     NaN            NaN       NaN
#
# ...

# %%
# Finding unique values for each column
# This will show in the data set, which one is Continuous, which is required for this assignment. It will also show which column is categorical as well. (Lecutre 9)
# Generally if the number of unique values are < 20 then the variable is likely to be a category otherwise continuous (lecture 9 - 1:17:03)
# this data type will assist with helping understand if there are anomalies in the prediction, we can use this data set to assist us with assessing what could be the issue. (Lecutre 9)
# Remember - that categorical is for more discrete values, whereas continuous variables is reflected in integers and float. (Lecutre 9)
# IN THIS ONE - LOOK FOR CATEGORICAL VARIABLES
FootballData.nunique()
# Out:
# name                            9202
# first_name                      4610
# age                               29
# nation                           167
# league                            74
# team                            1057
# goals_selection                   41
# selections_nation                135
# position                          12
# price                            132
# end_contract                       8
# goal_champ                       141
# assist_champ                     122
# own_goal_champ                     6
# sub_on_champ                     142
# sub_out_champ                    186
# yellow_card_champ                122
# second_yellow_card_champ          10
# red_card_champ                     9
# penalty_goal_champ               448
# conceded_goal_champ              164
# clean_sheet_champ                  1
# goal_cup                          29
# assist_cup                        25
# own_goal_cup                       4
# ...

# %% [markdown]
# **Step 7: Removing Unwanted Columns**
# There may be a number of qualtitive columns -
# *   Qualitative columns have been detected
# *   These columns have been detected as the following: name, first_name, nation, league, team and position

# %%
FootballData.drop(columns=['name','first_name','nation','league','team','position'])
# Out:
#        age  goals_selection  selections_nation    price  end_contract  \
# 0       28                0                 60  4000000           3.0
# 1       21                0                  0   800000           1.0
# 2       20                0                  1   650000           2.0
# 3       21                0                  0    50000           NaN
# 4       30                0                  0   200000           NaN
# ...    ...              ...                ...      ...           ...
# 12706   30                0                  0  1350000           2.0
# 12707   21                0                  0    75000           NaN
# 12708   18                0                  0    50000           2.0
# 12709   31                0                  0   125000           2.0
# 12710   24                0                  0   100000           2.0
#
#        goal_champ  assist_champ  own_goal_champ  sub_on_champ  sub_out_champ  \
# ...

# %% [markdown]
# **Step 8:  Visual Exploratory Data Analysis**
#
# - Visualise distribution of all the Categorical Predictor variables in the data using bar plots
# - We can spot categorical variables containing less than 20 Unique values AND there is a reptition of values, which means the data can be grouped by the those unique values.
# - Based on the Basic Exploration Data Analysis in the previous step, we can observe categorical predictors in the data
# Categorical Predictors include:
# - refer here
# - refer here
# We will use the bar charts to see how the data is distributed for these categorical columns.

# %%
#Plotting multiple bar charts at once for categorical vaiables
# Since there is no default function which can plot bar charts for multiple columns at once
# we are defining our own function for the same
# NOTE: FOR CATEGORICAL VARIABLES - we use a BOX-PLOT and look at them

def PlotBarCharts(inputData, colsToPlot):
    # %matplotlib inline

    import matplotlib.pyplot as plt

    #Generating multiple subplots (refer to 1:24:17 lecutre 9)
    fig, subPlot=plt.subplots(nrows=1, ncols=len(colsToPlot), figsize=(20,5))
    fig.suptitle('FootballData:'+str(colsToPlot))

    for colName, plotNumber in zip(colsToPlot, range(len(colsToPlot))):
      inputData.groupby(colName).size().plot(kind='bar',ax=subPlot[plotNumber])

# %%
##########################################################################################################
#Calling the function PlotBarCharts() we have created
# Categorical variables can be used in the Bar Charts
PlotBarCharts(FootballData, ['age', 'goals_selection', 'selections_nation','sub_on_champ'])

# %% [markdown]
# **Observations from Step 8 - Visual Exploratory Data Analysis**
#
# Notes from Lecture 9
# - Bar Charts have allowed interpretation on the two data columns (Lecture 9)
# - The Bar Charts represent the frequencies of each category inthe Y-axis and the category names in the X-axis. (Lecture 9)
# - In the ideal bar chart each category has comparable frequency*hence, there are enough rows for each catgory in the data for the ML/AL regression algorithm to learn. (Lecture 9)
# - if there is a column which shows too skewed distribution where there is only one domninant bar and the other categories are present very low numbers.
# - These kind columns may not very helpful in machine learning model development, we can confirm this with the correlation analysis step coming up, and take a final call to select or reject th column/data attribute.
# - In this dataset, it is worth noting that certain columns could be skewed.
# - The algorithms cannot find any rule like when the value is this when the target variable is that.
# Whenever in doubt, always investigate the column further.
# - Selected Categorical Variables (): The ones selected are (are they categorical variables?) for further analysis.
#
# - My findings were that the bar charts above, were skewed to the right, suggesting that the mean of the data for each graph, which means the "mean" of the data set will be the greatet, whilst the mode is the least.

# %% [markdown]
# **Step 9: Now Visualise Distribution of all the Continuous Predictor variables in the data using histograms.**
#
# Based on the Basic Exploratory Data Analysis, there are elevn continuous predictor variables: (this is where you input the qualitative variables instead, and CHANGE the word "continuous")

# %%
# Plotting histograms of multiple columns together
FootballData.hist(['age', 'goals_selection', 'selections_nation', 'sub_on_champ'])
#NOTE: Refer to 1:29:36 Lecture 9 - this supposed to have a histogram of all the columns.
#NOTE: We need to choose appropriate methods
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'goals_selection'}>],
#        [<Axes: title={'center': 'selections_nation'}>,
#         <Axes: title={'center': 'sub_on_champ'}>]], dtype=object)

# %% [markdown]
# Observations from Step 9 - refer to 1:31:26 of lecture slides - NEED TO UPDATE
# - Histogram interpretation (Lecture 9)
# - Each histogram shows us the data distribution for a single continuous variable. (Lecture 9)
# - The X-axis shows the range of values and Y-axis represent the number of values in that range. (Lecture 9)
# - For example, in the above histogram of "use coolumn name here), there are around 200 rows in data that has "column name" value between 90-100 (as an example) (Lecture 9)
# - The ideal outcome for histogram is a bell curve or slightly skewed bell curve.
# - If there is too much skeweness, then outlier removal treatment should be done and the column should be re-examined, and if that also does not solve the problem then only reject the column/data attribute. (Lecture 9)
# - Select Continouous Variables (or Qualitative) (Lecture 9)
#
# - My findings: there appears to be right side skewed, distributions of data across all histograms. These findings suggest that more values are placed closer to the maximum values of the data set. The data appears to have extreme outliers influencing the variables used to predict the price of a football player.

# %% [markdown]
# Step 10 Outlier Analysis - Lecture 9
# - Outliers are extreme values in the data
# - You can observe the tails in the histogram
# - Outlier must be treated one column/data attribute at a time
# - As the treatment will be slightly different each column.
# - Why I should analyse the outliers?
# - Outliers bias the building of  the machine learning models.
# - As the algorithms tires to fit the extreme value, it goes away from majoirty of the data.
# - Outlined below are two options to treat outliers in the data (1:33:14 Lecture 9).
# - Option-1: Delete outlier  Records. Only if there are just a few rows lost.
# - Option-2: Imputed the outlier values with a logical business value.
# Let us find out the most logical value to be replaced in the place of outliers by looking at the histogram. (1:33:30 Lecture 9)

# %%
#Replace Outliers for 'CRIM' - as an example from lecture
# Finding nearest values to 60 mark (coding below is a place holder - IT IS INCOMPLETE)
# THE ULTIMATE GOAL IS TO DELETE OR REPLACE OUTLIERS
FootballData
# Out:
#             name first_name  age       nation         league           team  \
# 0      Etheridge       Neil   28  Philippines  PremierLeague        Cardiff
# 1      LÃ©oNatel        NaN   21       Brazil  FirstDivision   APOELNicosia
# 2        Vidigal     AndrÃ©   20     Portugal  FirstDivision   APOELNicosia
# 3       Antoniou  BaiAndrew   21    Australia  FirstDivision   AlkiOroklini
# 4        Tribeau      Yoann   30       France  FirstDivision   AlkiOroklini
# ...          ...        ...  ...          ...            ...            ...
# 12706       Neto    Eduardo   30       Brazil       J1League  NagoyaGrampus
# 12707       Soma       Yuki   21        Japan       J1League  NagoyaGrampus
# 12708      Fujii     Haruya   18        Japan       J1League  NagoyaGrampus
# 12709     Takeda      Yohei   31        Japan       J1League  NagoyaGrampus
# 12710    Shibuya    Tsubasa   24        Japan       J1League  NagoyaGrampus
#
# ...

# %% [markdown]
# **Step 11: Visualising Data Distribution after outlier removal **

# %%
FootballData.hist('age', figsize=(18,5)) #being examples of data (refer to 1:34:39)
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %% [markdown]
# Observation from Step 11
# - The distribution has improved after the outlier treatment
# - The data still appears to be skewed to the right, however it is not as sharply skewed, which means that numbers overall are less grouped to the maximum, as per before.
#
#
# Step 12: Missing Values Analysis - Lecture 9
#
# -Missing values are treated for each column separately
#
# -If a column has more than 30% data missing, then missing value treatment cannot be done.
#
# -That column must be rejected because too much information is missing.
#
# -Outlined below are some options for treating missing values in data.
#
# -Delete the missing values with MEDIAN value for continuous variables.
#
# -Impute the missing values with MODE value for categorical variables
#
# -Interpolate the values based on nearby values.
#
# -Interpolate the values based on business logic (1:34:54)

# %%
# Finding how many missing values are there for each column (1:34:55 of Lecture 9) - this one can be achieved. (IF there are too many missing values - may need to speak with the tutor, because possibly replace with another data set 1:35:59 Lecture 9)
FootballData.isnull().sum()
# Out:
# name                               0
# first_name                      1009
# age                                0
# nation                             0
# league                             0
# team                               0
# goals_selection                    0
# selections_nation                  0
# position                           0
# price                              0
# end_contract                    3962
# goal_champ                         0
# assist_champ                       0
# own_goal_champ                     0
# sub_on_champ                       0
# sub_out_champ                      0
# yellow_card_champ                  0
# second_yellow_card_champ           0
# red_card_champ                     0
# penalty_goal_champ                 0
# conceded_goal_champ                0
# clean_sheet_champ                  0
# goal_cup                           0
# assist_cup                         0
# own_goal_cup                       0
# ...

# %% [markdown]
# Observations from Step 12: Missing Value Analysis
# - in this situation there NO missing data (however check again, once re-run the analysis)
# - So no removal of any data sample (rows) is needed.
#
# Refer to (1:36:02)

# %% [markdown]
# Step 13: Feature Selection (Attribute Selection) - further notes from Lecture 9
# - Now its time to finally choose the best column (Features) which are correlated to the Target variable.
# -This can be done by directly measuring the correlation values OR ANOVA analyse or Chi-Square test.
# - However, it is always helpful to visualise the relation between the Target variable/class variable and each of the predictors (features) to get a better sense of data.
# - Listed below are some of the techniques used for visualizing relationship between two variables as well as measuring the strength statistically.
# - Visual exploration of relationship between variables.
# - Continuous Vs Continuous - Scatter Plot
# - Categorical Vs Continuous - Box Plot
# - Categorical Vs Categorical - Grouped Bar Plots
# - Statistical measurement of rleationship strength between variables.
# - Continuous Vs Continuous - Correlation matrix

# %% [markdown]
# Relationship exploration: Continuous Vs Continous - Scatter Charts
# - When the Target variable is contiuous and the predictor is also continuous, we can visualise between the two variables using scatter plot and measures the strength of relation using a metric called pearsn's correlation value.

# %%
# Defining a new dataframe that is empty, and then copy all the categorical columns: 'age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup, assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent'
# Once this occurs, then you can create a categorical cols using the categorical determined columns, in order to graph a scatter plot. This is an alternative to the lecture material, which was covering continuous data.

CategoricalCols=pd.DataFrame(data=FootballData, columns=['age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup', 'assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent'])

# Plotting scatter chart for each predictor vs the target variable
for predictor in CategoricalCols:
    FootballData.plot.scatter(x=predictor, y='price', figsize=(10,5), title=predictor +'price')
    # there is supposed to be a graph here (check  the OneNOte that is being created - refer to 1:37:18)
    # in these graphs, make sure to explain the correlation of the variables
    # note: ALL The variables have been graphed: RM vs MEDV etc (refer to )
    # Remeber that the OUTPUT is going to be MEDV and the INPUT is going to be ANY of those variables.
    # What we can interpret from these is a trend, IF there is a visible trend or not.
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py:509: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# Lecture 9
#
# **Scatter Charts Interpretation**
# - Trend: You should try and see if there is a visible trend or not. There could be three scenarios.
# - Increasing Trend: This means both variables are positively correlated. In simpler terms, they are directly proportional to each other, if one value increases, then the other also increases. This is good for ML model building!
# - No Trend: You cannot see any clear increasing or decreasing trend. This means there is no correlation between the variables. Hence the predictor/feature may not be the best one for ML model building.
# - Based on this chart we can get a good idea about the predictor. f it will be useful or not. You can confirm this by looking at the correlation value in the next step.

# %% [markdown]
# **Step 14: Statstical Feature Slection (Continuous Vs Continuous) using Correlation Value - Lecture 9**
# - Pearson's correlation coefficient is a powerful metric for doing this.
# In the example (as per lecture) - at 1:39:19 (lecture 9), there are features that show the mathematical equations of the statistical analysis required into the assessment of each calcualtion.
#
# **Pearson's Correlation Coefficient**
# - This value can be calculated only between two numeric columns Correlation between (-1, 0) means invserley propoortional, the scatter plot will show a downward trend.
# - Correlation between (0,1) means directly proportional in the scatter plot will show a upward trend.
# - Correlation near {0} means No relationship, the scatter plot will show no clear trend.
# - If Correlation value between two variables is > 0.5 in magnitude, it indicates good relationship the sign does not matter.

# %%
#Calculating correlation matrix
CategoricalCols=['age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup', 'assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent' ]

#Creating the correlation matrix
CorrelationData=FootballData[CategoricalCols].corr()
CorrelationData
#there would be a table below, generated, however there would be a table below.
# Remember anything that is close to .6 and 1.0 is considered close correlation, it is very low, then you might be seeing that some of the columns are very low.

# Remember, anything above .5 is good enough, anything that is less than .5 then we will not select that variable. (Refer to 1:40:31) - it means that if we find that there are some variables that do not meet tthis critera, then we can delete these.
# Out:
#                                    age  goals_selection  selections_nation  \
# age                           1.000000         0.130403           0.267569
# goals_selection               0.130403         1.000000           0.673154
# selections_nation             0.267569         0.673154           1.000000
# sub_on_champ                  0.302435         0.239563           0.233470
# sub_out_champ                 0.379878         0.320459           0.322720
# yellow_card_champ             0.494291         0.202477           0.325144
# penalty_goal_champ            0.317545        -0.061595           0.087380
# conceded_goal_champ           0.315344        -0.069937           0.129683
# goal_cup                      0.186554         0.390672           0.285956
# assist_cup                    0.177171         0.350969           0.313668
# sub_on_cup                    0.169667         0.205220           0.210929
# ...

# %% [markdown]
# Step 15: Relationship Exploration: Categorical Vs Continuous - Blox Plots
#
# - When the target variable is Continuous and the predictor variable is Categorical we analyze the relation using Boxplots, and
# -Measure the strength of relation using Anova test.

# %%
# Defining a new dataframe to allow for the addition of a list to be added, which will mean that the new dataframe can be called "Categorical"

# Box plots for continuous Target Variable "price" and Categorical preditors
CategoricalColsLists=['age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'price','penalty_goal_cup']

import matplotlib.pyplot as plt
fig, PlotCanvas=plt.subplots(nrows=1, ncols=len(CategoricalColsLists), figsize=(100,50))

# Creating box plots for each categorical predictor against the Target Variable "price"
for PredictorCol , i in zip(CategoricalColsLists, range(len(CategoricalColsLists))):
  FootballData.boxplot(column='price', by=PredictorCol, figsize=(5,5), vert=True, ax=PlotCanvas[i])


# import matplotlib.pyplot as plt
#fig, PlotCanvas=plt.subpplots in zip(CategoricalColsLists, range(len(CategoricalColsList))):
  #FootballData.boxplot(column='price',by=PredictorCol, figsize=(5,5), vert=True, ax=PlotCanvas[i])
  # there are supposed to be graphs generated below, howevever, need to install Matlab and potentially look at this being Qualitative Data. - refer to 1:41:09

  #boxplots - these will show lots of things, such as how far away is the mean, what is the spread of each data, what are the extreme values, and what are the outliers, and if they are close together, they should be good enough for modelling. IF there are TOO many outliers, then some of the outliers may need to be deleted. (refer to 1:42:00 of Lecutre 9)

# %% [markdown]
# Observations from Step 15: Box-Plots Interpretation - Lecture 9
# - These plots gives an idea aobut the data distribution of continuous predictor in the Y-axis for each category (Boxes are in the same line), that means the continuous variable has NO effect on the target variable. Hence, the variables are not correlated to each other.
# - On the other hand if the distribution is different for each category (the boxes are not in the same line). it hints that these varaibles might be correlated with price.
# - For this database, both the categorical predictors looks correlated with the Target variable.
# We confirm this by looking at the results of ANOVA test below.

# %% [markdown]
# **Step 16: Statistical Feature Selection (Categorical) using ANOVA test - Lecture 9**
# - Analysis of variance (ANOVA) is performed to check if there is any relationship between the given continuous and categorical variable.
# - Assumption (Ho) Null Hypothesis: There is NO relation between the given variables.
# - The average(mean) values of the numeric Target variable is same for all the groups in the categorical Predictor vaiable).
# - ANOVA Test result: Probability of H0 (Null Hypothesis being true

# %%
# Defining a function to find the statistical relationship with all the categorical varaibles
def FunctionAnova(inpData, TargetVariable, CategoricalPredictorList):
    from scipy.stats import f_oneway

    # Creating an empty list of final selected predictors
    SelectedPredictors=[]


    print('##### ANOVA Results #####\n')
    for predictor in CategoricalPredictorList:

      #CategoryGroupLists=inpData.groupby(predictor(TargetVariable).apply(list))
      CategoryGroupLists = inpData.groupby(predictor)[TargetVariable].apply(list)
      AnovaResults = f_oneway(*CategoryGroupLists)

      # If the ANOVA P-Value is <0.05, that means we reject H0
      if (AnovaResults[1] < 0.05):
        print(predictor, 'is correlated with', TargetVariable, '|P-Value:', AnovaResults[1])
        SelectedPredictors.append(predictor)
      else:
        print(predictor, 'is NOT correlated with', TargetVariable, '|P-Value:,', AnovaResults[1])
      return(SelectedPredictors)

# %%
#Calling the function to check which categorical variable are correlated with target
CategoricalPredictorList=['age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup', 'assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent']
#FunctionAnova(inpData=FootballData,TargetVariable='price',CategoricalPredictorList=CategoricalPredictorList)
FunctionAnova(inpData=FootballData, TargetVariable='price', CategoricalPredictorList=CategoricalPredictorList)

# this is a function of variable arguments, this means that "inpData=FootballData" should be coded in first.
# Out:
# ##### ANOVA Results #####
#
# age is correlated with price |P-Value: 4.0759706165863345e-07
# ['age']

# %% [markdown]
# **Observations from Step 16**
# - The results of ANOVA confirm our visual analysis using box plots above
# - All categorical variables are correlate with the Target variable
# - This is something you can guess by looking at the box plots.
# - Final selected Categorical columns: ('age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup', 'assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent')

# %% [markdown]
# Selecting final Predictors/Features for building Machine Learning/AI model
# - Based on the extensive tests with exploratory data analsysis we can select the final features/predictors/columns for machine learning model building as
# -'age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup', 'assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent'
# - THIS IMPORTANT - BECAUSE THESE ARE EXAMPLES OF THE FINAL VARIABLES. (refer to 1:44:47 Lecutre 9)

# %%
SelectColumns=['age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup', 'assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent' ]
DataForML=FootballData[SelectColumns]
DataForML.head()
# Out:
#    age  goals_selection  selections_nation  sub_on_champ  sub_out_champ  \
# 0   28                0                 60             0              1
# 1   21                0                  0             6              7
# 2   20                0                  1            27             11
# 3   21                0                  0             1              0
# 4   30                0                  0            30             13
#
#    yellow_card_champ  penalty_goal_champ  conceded_goal_champ  goal_cup  \
# 0                  9                 237                   59         0
# 1                  0                   0                    0         0
# 2                  3                   1                    0         3
# 3                  0                   0                    0         0
# 4                  3                   0                    0         0
#
#    assist_cup  ...  yellow_card_cup  red_card_cup  penalty_goal_cup  \
# ...

# %%
# Saving this file final data subset for reference during dmeployment
DataForML.to_pickle('DataForML.pk1')

# %% [markdown]
# **Step 17: Data Pre-processing for Machine LEarning Model Building or Model Development** - Lecture 9
# - List of steps that needs to be performed on predictor variables before data can be used for machine learning.
# - Coverting each Ordinal Categorical columns to numeric
# - Converting Binary Norminal Categorical columns to numeric using 1/20 Mapping
# - converting all other categorical columns to numeric using pd.get_dummies()
# - Data transformation (Optional) Standardization/Normalization/log/sqrt. Important if you are using distance based algorithm like KNN or Neural Networks.
# - Converting the ordinal variable to numeric - In this data there is no ordinal categorical variable
# - Converting the binary nominal variable to numeric using 1/10 mapping. There is no binary variable in string format in this data.

# %% [markdown]
# Converting the nominal variable to numeric using get_dummies()

# %%
# Treating all the nominal variables at once using dummy variables
DataForML_Numeric=pd.get_dummies(DataForML)

# Adding Target Variable to the data
DataForML_Numeric['price']=FootballData['price']

# Priting sample rows (this should have a table below 1:45:12)
DataForML_Numeric.head()
# Out:
#    age  goals_selection  selections_nation  sub_on_champ  sub_out_champ  \
# 0   28                0                 60             0              1
# 1   21                0                  0             6              7
# 2   20                0                  1            27             11
# 3   21                0                  0             1              0
# 4   30                0                  0            30             13
#
#    yellow_card_champ  penalty_goal_champ  conceded_goal_champ  goal_cup  \
# 0                  9                 237                   59         0
# 1                  0                   0                    0         0
# 2                  3                   1                    0         3
# 3                  0                   0                    0         0
# 4                  3                   0                    0         0
#
#    assist_cup  ...  red_card_cup  penalty_goal_cup  goal_continent  \
# ...

# %% [markdown]
# **Step 18: Machine Learning Model Development**
# -Splitting the data into Training and Testing Sample
# -We don't use the full data for creating the model (training data)/
# - Some data is randomly selected and kept aside for checking how good the model is.
# - This is known as Testing Data and the remaining data called Training data on which the model is built.
# -Typically 70% of data is used as Training data and the rest 30% is used as Testing data.

# %%
# Printing all the column names for our reference
DataForML_Numeric.columns #this should apply a Index below refer to 1:45:47)

# %%
from typing import ValuesView
from typing import ValuesView
from typing_extensions import dataclass_transform
# Separate Target Variable and Predictor Variables
TargetVariable='price'
Predictors=['age', 'goals_selection', 'selections_nation', 'sub_on_champ', 'sub_out_champ', 'yellow_card_champ', 'penalty_goal_champ', 'conceded_goal_champ', 'goal_cup', 'assist_cup', 'sub_on_cup', 'sub_out_cup', 'yellow_card_cup', 'red_card_cup', 'penalty_goal_cup', 'goal_continent', 'assist_continent', 'sub_on_continent', 'sub_out_continent', 'yellow_card_continent', 'second_yellow_card_continent', 'red_card_continent']

X=DataForML_Numeric[Predictors].values
y=DataForML_Numeric[TargetVariable].values

#Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.3, random_state=428)

# %% [markdown]
# **Step 19: Standardisation/Normalisation of data** =- Lecture 9
# - You can choose not to run this step if you want to compare the resultant accuracy of the transformation with the accuracy of raw data (Optional Step) - Lecture 9
# - However, if you are using KNN or Neural Networks then this step becomes necessary. - lecture 9

# %%
### Standardisation of data ###
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Choose either standardization or Normalization
# On this data Min Max Normalization produced better results

# Choose between standardization and MinMax normalization
#PredictorScale=StandardScaler()
PredictorScaler=MinMaxScaler()

# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(X)

#Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Sanity check for the sampled data
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# there are results below)
# Out:
# (8344, 22)
# (8344,)
# (3576, 22)
# (3576,)

# %% [markdown]
# **Step 20: Multiple Linear Regression Algorithm for ML/AI model building**

# %%
from typing import MappingView
# Multiple Linear Regression
from sklearn.linear_model import LinearRegression
RegModel = LinearRegression()

#Printing all the parameters of Linear Regression
print(RegModel)

# Creating the model on Training Data
LREG=RegModel.fit(X_train,y_train)
prediction=LREG.predict(X_test)

from sklearn import metrics
# Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, LREG.predict(X_train)))

##############################################################################################
print('\n##### Model Validation and Accuracy Calculations ###############')

# Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

# Printing sample prediction values
print(TestingDataResults.head())

#Calculating the error for each new row
TestingDataResults['APE']=100*((abs(
    TestingDataResults['price']-TestingDataResults['Predictedprice']))/TestingDataResults['price'])

MAPE=np.mean(TestingDataResults['goals_selection'])
MedianMAPE=np.median(TestingDataResults['goals_selection'])

Accuracy = 100 - MAPE
MedianAccuracy=100 - MedianMAPE
print('Mean Accuracy on test data:', Accuracy) #Can be negative sometimes due to outlier
print('Median Accuracy on test data', MedianAccuracy)

def Accuracy_Score(orig, pred):
  MAPE = np.mean(100 * (np.abs(orig-pred)/orig))
  return (100-MAPE)

# custom scoring MAPE calculation
from sklearn.metrics import make_scorer
custom_Scoring=make_scorer(Accuracy_Score, greater_is_better=True)

#Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross Validation on a given algorithm
# Passsing full data X and y because the K-fold will split the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X, y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Average Accuracy of the model:',round(Accuracy_Values.mean()),2)
# Out:
# LinearRegression()
# R2 Value: 0.32308228899724234
#
# ##### Model Validation and Accuracy Calculations ###############
#    age  goals_selection  selections_nation  sub_on_champ  sub_out_champ  \
# 0   28                0                  0            39             60
# 1   20                0                  0            20              9
# 2   31                1                 29            51             82
# 3   27                0                  0             6             10
# 4   21                0                  0             0              0
#
#    yellow_card_champ  penalty_goal_champ  conceded_goal_champ  goal_cup  \
# 0                 34                  11                    0         0
# 1                  2                   0                    0         0
# 2                 69                   1                    0         1
# 3                 12                   0                    0         0
# ...

# %%
#Importing cross validation function from sklearn
from sklearn.model_selection import cross_val_score

# Running 10-Fold Cross validation on a given algorithm
#Passing full data x and y because the k-fold will spliot the data and automatically choose train/test
Accuracy_Values=cross_val_score(RegModel, X, y, cv=10, scoring=custom_Scoring)
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_Values)
print('\nFinal Averages Accuracy of the model:',round(Accuracy_Values.mean(),2))
# Out:
# Accuracy values for 10-fold Cross Validation:
#  [ -225.95538211  -922.81149382  -484.84679468  -175.18824008
#  -1138.89196669 -1025.97784332  -630.21644963  -767.64972233
#  -2070.41749938 -1506.54416994]
#
# Final Averages Accuracy of the model: -894.85

# %% [markdown]
# **Step 21: AdaBoost Algorithm For ML/AI model building**

# %%
# Adaboost (Boosting of multiple Decision Trees)
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# choosing decision tree with 6 level as the weak learner
DTR=DecisionTreeRegressor(max_depth=3)
RegModel=AdaBoostRegressor(n_estimators=100, base_estimator=DTR, learning_rate=0.04)

print(RegModel)

AB=RegModel.fit(X_train, y_train)
prediction=AB.predict(X_test)


#Measuring Goodness of fit in Training data
print('R2 Value:',metrics.r2_score(y_train, AB.predict(X_train)))

#Plotting the feature importance for Top 10 most important columns
# %matplotlib inline
feature_importance = pd.Series(AB.feature_importances_, index=Predictors)
feature_importance.nlargest(10).plot(kind='barh')
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=3),
#                   learning_rate=0.04, n_estimators=100)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# R2 Value: 0.5624082061835336
# <Axes: >

# %%
#Printing some sample values of prediction
TestingDataResults=pd.DataFrame(data=X_test, columns=Predictors)
TestingDataResults[TargetVariable]=y_test
TestingDataResults[('Predicted'+TargetVariable)]=np.round(prediction)

#Printing sample prediction values
print(TestingDataResults.head())

# Calculating the error for each row
TestingDataResults['APE']=100*((abs(
      TestingDataResults['price']-TestingDataResults['Predictedprice']))/TestingDataResults['price'])

MAPE=np.mean(TestingDataResults['APE'])
MedianMAPE=np.median(TestingDataResults['APE'])

Accuracy =100 - MAPE
MedianAccuracy=100-MedianMAPE
print('Mean Accuracy on test data:',Accuracy) # Can be a negative sometimes due to outlier
print('Median Accuracy on test data:',MedianAccuracy)

# Defining a custom function to calculate accuracy
# Make sure there are no zeros in the Target variable if you are using MAPE
def Accuracy_Score(orig,pred):
  MAPE=np.mean(100*(np.abs(orig-pred)/orig))
  #print('#'*70, 'Accuracy:', 100-MAPE)
  return(100-MAPE)
# Out:
#    age  goals_selection  selections_nation  sub_on_champ  sub_out_champ  \
# 0   28                0                  0            39             60
# 1   20                0                  0            20              9
# 2   31                1                 29            51             82
# 3   27                0                  0             6             10
# 4   21                0                  0             0              0
#
#    yellow_card_champ  penalty_goal_champ  conceded_goal_champ  goal_cup  \
# 0                 34                  11                    0         0
# 1                  2                   0                    0         0
# 2                 69                   1                    0         1
# 3                 12                   0                    0         0
# 4                  5                  41                   14         0
#
#    assist_cup  ...  penalty_goal_cup  goal_continent  assist_continent  \
# ...

# %% [markdown]
# **Observations for Step 21**
#
# Given the mean accuracy and median accuracy on the test data are both negatives, this means there is something incorrect with the process invovled in predicting the price of a football player, using the variables chosen. This is because the value output should be between 0 and 1. The outcome suggests there is limited evidence a proficient model of price prediction, has been attained in the project. Possibly the continuation to utilise data that has significant outliers, has caused the data model to be limited in response to providing a reliable price prediction model. Given the outcome of using AdaBooster, and the negative values attained, it can be assumed that the model is performing poorly.
